# %% [markdown]
# ### IV.A. Основные Концепции Машинного Обучения
#
# **1. Три Типа Машинного Обучения:**
#
# *   **Обучение с учителем (Supervised Learning):** 👨‍🏫📚
#     *   **Суть:** Обучение на **размеченных данных** (есть признаки и правильные ответы/метки).
#     *   **Цель:** Научиться предсказывать правильный ответ для новых данных.
#     *   **Задачи:**
#         *   **Классификация:** Предсказание категории (спам/не спам, кошка/собака).
#         *   **Регрессия:** Предсказание числового значения (цена дома, температура).
# *   **Обучение без учителя (Unsupervised Learning):** 🕵️‍♂️🌍
#     *   **Суть:** Обучение на **неразмеченных данных** (только признаки, без ответов).
#     *   **Цель:** Поиск скрытой структуры, закономерностей, группировка данных.
#     *   **Задачи:**
#         *   **Кластеризация:** Группировка схожих объектов.
#         *   **Понижение размерности:** Уменьшение числа признаков с сохранением информации.
#         *   **Поиск аномалий:** Выявление необычных объектов.
# *   **Обучение с подкреплением (Reinforcement Learning):** 🎮🤖
#     *   **Суть:** Агент обучается принимать решения в среде для максимизации **награды**. Обучение через **пробы и ошибки** (получение наград/штрафов).
#     *   **Цель:** Выработать оптимальную стратегию (политику) действий.
#     *   **Задачи:** Игры, робототехника, рекомендательные системы, оптимизация.
#
# **2. Основные Этапы Разработки ML-модели (ML Pipeline):**
#
# 1.  **Сбор данных (Data Collection):** 📊📥 Получение сырых данных.
# 2.  **Предобработка данных (Data Preprocessing):** 🧹✨ Очистка (пропуски, ошибки, дубликаты), форматирование, масштабирование данных.
# 3.  **Инженерия признаков (Feature Engineering):** 🛠️⚙️ Отбор, создание, преобразование признаков для улучшения модели.
# 4.  **Выбор модели (Model Selection):** 🧠🧰 Выбор подходящего алгоритма (линейная/логистическая регрессия, деревья, SVM, нейросети и т.д.) в зависимости от задачи и данных.
# 5.  **Обучение модели (Model Training):** 🏋️‍♀️💪 Настройка параметров модели на обучающих данных для минимизации ошибки.
# 6.  **Оценка модели (Model Evaluation):** 📏🧐 Оценка качества обученной модели на *тестовых* (невиданных) данных с использованием метрик.
# 7.  **Настройка гиперпараметров (Hyperparameter Tuning):** ⚙️🔧 Подбор оптимальных значений *внешних* параметров модели (не обучаемых напрямую), например, `learning_rate`, `max_depth`, `alpha`. Часто используется кросс-валидация.
# 8.  **Развертывание модели (Model Deployment):** 🚀🛰️ Внедрение модели в рабочую среду (приложение, API).
# 9.  **Мониторинг и поддержка (Monitoring & Maintenance):** 📊🛠️ Отслеживание производительности модели в реальных условиях, переобучение при необходимости (из-за "дрейфа данных").
#
# ---

# %% [markdown]
# ### IV.B. Метрики Оценки Качества Моделей
#
# Метрики — числовые показатели для количественной оценки производительности модели. Выбор метрики зависит от типа задачи (регрессия или классификация) и конкретных целей.
#
# #### IV.B.1. Метрики для Задач РЕГРЕССИИ
#
# Оценивают модели, предсказывающие числовые значения.
#
# 1.  **MSE (Mean Squared Error) – Среднеквадратичная Ошибка:**
#     *   **Формула:** $MSE = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i)^2$
#     *   **Интерпретация:** Средний квадрат разницы между истинным ($y_i$) и предсказанным ($\hat{y}_i$) значениями.
#     *   **Свойства:** Сильно штрафует за большие ошибки. Чувствительна к выбросам. Единицы измерения - квадрат единиц цели. **Минимизируется.**
# 2.  **MAE (Mean Absolute Error) – Средняя Абсолютная Ошибка:**
#     *   **Формула:** $MAE = \frac{1}{N} \sum_{i=1}^{N} |y_i - \hat{y}_i|$
#     *   **Интерпретация:** Средний модуль разницы между истинным и предсказанным значениями.
#     *   **Свойства:** Менее чувствительна к выбросам, чем MSE. Единицы измерения совпадают с единицами цели (более интерпретируема). **Минимизируется.**
# 3.  **MAPE (Mean Absolute Percentage Error) – Средняя Абсолютная Процентная Ошибка:**
#     *   **Формула:** $MAPE = \frac{100\%}{N} \sum_{i=1}^{N} \left| \frac{y_i - \hat{y}_i}{y_i} \right|$
#     *   **Интерпретация:** Средняя ошибка в процентах от истинного значения.
#     *   **Свойства:** Легко интерпретируется. Безразмерная. **Неприменима, если истинные значения $y_i$ могут быть равны нулю или близки к нему.** **Минимизируется.**
#
# #### IV.B.2. Метрики для Задач КЛАССИФИКАЦИИ
#
# Оценивают модели, предсказывающие категориальные метки. Часто основаны на **Confusion Matrix**.
#
# **Confusion Matrix (Матрица Ошибок):**
# Таблица, показывающая соотношение истинных и предсказанных классов (для бинарной классификации):
#
# |                       | Предсказано: Positive | Предсказано: Negative |
# | :-------------------- | :-------------------: | :-------------------: |
# | **Истинно: Positive** |     **TP** (True Pos) |     **FN** (False Neg)|
# | **Истинно: Negative** |     **FP** (False Pos)|     **TN** (True Neg) |
#
# *   **TP:** Верно предсказанные Positive.
# *   **TN:** Верно предсказанные Negative.
# *   **FP:** Ошибочно предсказанные Positive (Ошибка I рода, "ложная тревога").
# *   **FN:** Ошибочно предсказанные Negative (Ошибка II рода, "пропуск цели").
#
# **Основные Метрики:**
#
# 1.  **Accuracy (Доля правильных ответов):**
#     *   **Формула:** $Accuracy = \frac{TP + TN}{TP + TN + FP + FN}$
#     *   **Интерпретация:** Доля всех верно классифицированных объектов.
#     *   **Ограничение:** Может быть обманчиво высокой на **несбалансированных данных**.
# 2.  **Precision (Точность):**
#     *   **Формула:** $Precision = \frac{TP}{TP + FP}$
#     *   **Интерпретация:** Доля объектов, действительно являющихся Positive, среди всех, что модель предсказала как Positive. Отвечает на вопрос: "Если модель сказала Positive, насколько ей верить?"
#     *   **Важно:** Высокий Precision означает мало ложных срабатываний (FP).
# 3.  **Recall (Полнота / Чувствительность / TPR):**
#     *   **Формула:** $Recall = \frac{TP}{TP + FN}$
#     *   **Интерпретация:** Доля объектов, верно найденных моделью как Positive, среди всех реально Positive объектов. Отвечает на вопрос: "Сколько реальных Positive объектов модель нашла?"
#     *   **Важно:** Высокий Recall означает мало пропусков цели (FN).
# 4.  **F1-score (F-мера):**
#     *   **Формула:** $F1 = 2 \times \frac{Precision \times Recall}{Precision + Recall} = \frac{2 \times TP}{2 \times TP + FP + FN}$
#     *   **Интерпретация:** Гармоническое среднее Precision и Recall. Дает баланс между ними.
#     *   **Важно:** Особенно полезна для **несбалансированных данных**, когда важны и Precision, и Recall. Высокий F1 достигается только если обе метрики высоки.
# 5.  **ROC AUC (Area Under the Receiver Operating Characteristic Curve):**
#     *   **ROC-кривая:** График зависимости **TPR (Recall)** от **FPR (False Positive Rate)** при изменении порога классификации. ($FPR = \frac{FP}{FP + TN}$)
#     *   **Интерпретация AUC:** Площадь под ROC-кривой. Вероятность того, что модель ранжирует случайно выбранный Positive объект выше, чем случайно выбранный Negative.
#     *   **Свойства:**
#         *   AUC = 1: Идеальный классификатор.
#         *   AUC = 0.5: Случайный классификатор.
#         *   AUC > 0.5: Модель лучше случайной.
#     *   **Важно:** Оценивает качество модели **независимо от порога**. Относительно устойчива к дисбалансу классов.
# 6.  **PR AUC (Area Under the Precision-Recall Curve):**
#     *   **PR-кривая:** График зависимости **Precision** от **Recall** при изменении порога классификации.
#     *   **Интерпретация AUC:** Площадь под PR-кривой. Агрегирует Precision по разным уровням Recall.
#     *   **Свойства:**
#         *   AUC = 1: Идеальный классификатор (в терминах P и R).
#         *   Базовый уровень (случайный классификатор) зависит от доли Positive класса (ниже 0.5 при дисбалансе).
#     *   **Важно:** Более информативна, чем ROC AUC, на **сильно несбалансированных данных**, когда важна производительность именно на редком Positive классе.
#
# ---
#
# ### IV.C. Переобучение, Недообучение и Компромисс Смещения-Дисперсии
#
# **1. Недообучение (Underfitting):**
# *   **Проблема:** Модель **слишком проста**, не может уловить закономерности в данных.
# *   **Характеристики:** **Плохое качество** на *обучающей* и *тестовой* выборках.
# *   **Причина:** **Высокое смещение (High Bias)** - сильные упрощающие предположения модели. **Низкая дисперсия (Low Variance)** - модель нечувствительна к данным.
# *   **Борьба:** Усложнить модель, добавить/улучшить признаки, уменьшить регуляризацию.
#
# **2. Переобучение (Overfitting):**
# *   **Проблема:** Модель **слишком сложна**, "запоминает" обучающие данные (включая шум), но плохо обобщает на новые.
# *   **Характеристики:** **Отличное качество** на *обучающей* выборке, **значительно худшее** на *тестовой*. Большой разрыв между метриками на обучении и тесте (Overfitting Gap).
# *   **Причина:** **Высокая дисперсия (High Variance)** - сильная чувствительность к обучающим данным. **Низкое смещение (Low Bias)** - модель хорошо описывает обучение.
# *   **Борьба:** Упростить модель, регуляризация, кросс-валидация, ранняя остановка, отбор признаков, ансамбли, больше данных.
#
# **3. Компромисс Смещения-Дисперсии (Bias-Variance Tradeoff):**
# *   **Суть:** Нельзя одновременно минимизировать и Bias, и Variance. Уменьшение одного часто ведет к увеличению другого.
# *   **Цель:** Найти **баланс** между Bias и Variance для минимизации **общей ошибки на новых данных**.
# *   **Визуализация:** U-образная кривая ошибки в зависимости от сложности модели. Минимум общей ошибки достигается при оптимальной сложности.
#
# **(Регуляризация - ключевой инструмент управления этим компромиссом, см. раздел о Линейной Регрессии).**
#
# ---
# Этот вариант убирает повторные определения, сокращает описания, но сохраняет суть каждого понятия, формулы и основные выводы. Код сведен к примерам использования `sklearn` или ссылкам на предыдущие блоки.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression # Используем простой классификатор для примера
from sklearn.metrics import (accuracy_score,
                             precision_score,
                             recall_score,
                             f1_score,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                             roc_auc_score,
                             roc_curve,             # Для построения ROC-кривой
                             precision_recall_curve, # Для построения PR-кривой
                             auc                    # Для вычисления площади под кривой (PR AUC)
                            )

# 1. Генерация синтетических данных для бинарной классификации
# Сделаем классы немного несбалансированными для наглядности метрик
X, y = make_classification(n_samples=1000, n_features=20, n_informative=10,
                           n_redundant=5, n_classes=2, weights=[0.8, 0.2], # 80% класс 0, 20% класс 1
                           flip_y=0.05, random_state=42)

# 2. Разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# 3. Обучение модели (Логистическая Регрессия для примера)
model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

# 4. Получение предсказаний на тестовой выборке
y_pred = model.predict(X_test)              # Предсказанные классы
y_proba = model.predict_proba(X_test)       # Предсказанные вероятности [P(class=0), P(class=1)]
y_proba_positive = y_proba[:, 1]            # Вероятности только для положительного класса (класса 1)

print("--- Расчет и отображение метрик ---")

# 5. Confusion Matrix (Матрица Ошибок)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

print("\nConfusion Matrix:")
# Выведем текстовый вариант для ясности
tn, fp, fn, tp = cm.ravel()
print(f"TN: {tn}, FP: {fp}")
print(f"FN: {fn}, TP: {tp}")

# Визуализация Confusion Matrix
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
plt.close() # Закрываем график матрицы ошибок

# 6. Accuracy, Precision, Recall, F1-score
accuracy = accuracy_score(y_test, y_pred)
# Расчет для положительного класса (pos_label=1 по умолчанию)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"\nAccuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# 7. ROC AUC Score
roc_auc = roc_auc_score(y_test, y_proba_positive)
print(f"ROC AUC:   {roc_auc:.4f}")

# 8. Построение ROC-кривой
fpr, tpr, roc_thresholds = roc_curve(y_test, y_proba_positive)

plt.figure(figsize=(7, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random classifier') # Линия случайного угадывания
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
plt.close() # Закрываем график ROC

# 9. PR AUC Score и построение PR-кривой
precision_curve, recall_curve, pr_thresholds = precision_recall_curve(y_test, y_proba_positive)
pr_auc = auc(recall_curve, precision_curve) # Вычисляем площадь под PR-кривой
print(f"\nPR AUC:    {pr_auc:.4f}")

plt.figure(figsize=(7, 6))
plt.plot(recall_curve, precision_curve, color='blue', lw=2, label=f'PR curve (area = {pr_auc:.2f})')
# Базовый уровень для PR AUC (доля положительного класса)
baseline = y_test.sum() / len(y_test)
plt.plot([0, 1], [baseline, baseline], linestyle='--', color='red', label=f'Baseline (No Skill = {baseline:.2f})')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.grid(True)
plt.show()
plt.close() # Закрываем график PR
# Out:
# --- Расчет и отображение метрик ---
#
# Confusion Matrix:
# TN: 222, FP: 12
# FN: 28, TP: 38
# Accuracy:  0.8667
# Precision: 0.7600
# Recall:    0.5758
# F1 Score:  0.6552
# ROC AUC:   0.9047
# PR AUC:    0.7685

# %% [markdown]
# ### IV.C. Переобучение, Недообучение и Компромисс Смещения-Дисперсии
#
# **1. Недообучение (Underfitting):**
# *   **Проблема:** Модель **слишком проста**, не может уловить закономерности в данных.
# *   **Характеристики:** **Плохое качество** на *обучающей* и *тестовой* выборках.
# *   **Причина:** **Высокое смещение (High Bias)** - сильные упрощающие предположения модели. **Низкая дисперсия (Low Variance)** - модель нечувствительна к данным.
# *   **Борьба:** Усложнить модель, добавить/улучшить признаки, уменьшить регуляризацию.
#
# **2. Переобучение (Overfitting):**
# *   **Проблема:** Модель **слишком сложна**, "запоминает" обучающие данные (включая шум), но плохо обобщает на новые.
# *   **Характеристики:** **Отличное качество** на *обучающей* выборке, **значительно худшее** на *тестовой*. Большой разрыв между метриками на обучении и тесте (Overfitting Gap).
# *   **Причина:** **Высокая дисперсия (High Variance)** - сильная чувствительность к обучающим данным. **Низкое смещение (Low Bias)** - модель хорошо описывает обучение.
# *   **Борьба:** Упростить модель, регуляризация, кросс-валидация, ранняя остановка, отбор признаков, ансамбли, больше данных.
#
# **3. Компромисс Смещения-Дисперсии (Bias-Variance Tradeoff):**
# *   **Суть:** Нельзя одновременно минимизировать и Bias, и Variance. Уменьшение одного часто ведет к увеличению другого.
# *   **Цель:** Найти **баланс** между Bias и Variance для минимизации **общей ошибки на новых данных**.
# *   **Визуализация:** U-образная кривая ошибки в зависимости от сложности модели. Минимум общей ошибки достигается при оптимальной сложности.
#
# **(Регуляризация - ключевой инструмент управления этим компромиссом, см. раздел о Линейной Регрессии).**
